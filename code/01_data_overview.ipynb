# %% [markdown]
# # 문제 정의 & 데이터 이해

# %% [markdown]
# ### 실험 목적 정의
# - 게임 내 첫 번째 관문의 위치가 레벨 30에서 레벨 40으로 변경됐을 때, retention이 증가하는지 검증한다.

# %% [markdown]
# ---
# # 데이터 구조 및 컬럼 이해

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/cookie_cats.csv')
df.sample(5)
# Out:
#         userid  version  sum_gamerounds  retention_1  retention_7
# 22559  2513129  gate_30              16        False        False
# 40535  4484909  gate_40              11        False        False
# 27840  3101778  gate_40               2        False        False
# 49534  5494116  gate_40               4        False        False
# 74080  8209235  gate_30               5        False        False

# %% [markdown]
# #### 변수
# - userid : 유저 고유 ID
# - version : 게이트 설치 위치 (gate_30/gate_40)
# - sum_gamerounds : 설치 후 14일 동안 플레이어가 플레이 한 라운드 수
# - retention_1 : 설치 후 1일째에 다시 게임을 플레이 했는지 여부
# - retention_7 : 설치 후 7일째에 다시 게임을 플레이 했는지 여부

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90189 entries, 0 to 90188
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   userid          90189 non-null  int64
#  1   version         90189 non-null  object
#  2   sum_gamerounds  90189 non-null  int64
#  3   retention_1     90189 non-null  bool
#  4   retention_7     90189 non-null  bool
# dtypes: bool(2), int64(2), object(1)
# memory usage: 2.2+ MB

# %%
print("userid unique counts: ", df.userid.nunique())
# Out:
# userid unique counts:  90189

# %%
df.version.value_counts('False')
# Out:
# version
# gate_40    0.504374
# gate_30    0.495626
# Name: proportion, dtype: float64

# %% [markdown]
# ---
# # 가설 설정

# %% [markdown]
# ### 가설 1 : D1 retention

# %% [markdown]
# - 귀무가설 (H0) : gate 40의 D1 retention은 gate 30의 D1 retention이 같다.
# - 대립가설 (H1) : gate 40의 D1 retention이 gate 30의 D1 retention보다 크다.

# %% [markdown]
# ### 가설 2 : D7 retention

# %% [markdown]
# - 귀무가설 (H0) : gate 40의 D7 retention은 gate 30의 D7 retention이 같다.
# - 대립가설 (H1) : gate 40의 D7 retention이 gate 30의 D7 retention보다 크다.

# %% [markdown]
# ---
# # KPI 정의

# %% [markdown]
# - **D7 retention이 통계적으로 유의하게 증가할 경우, gate 40을 채택한다.**
#
# - Primary KPI
#     > D7 retention
#     설치 후 7일 이내 최소 1회 이상 재접속한 유저의 비율
#
# - Secondary KPI
#     > D1 retention:
#     설치 후 1일 이내 재접속한 유저의 비율
#
# - Third KPI
#     > 하루 평균 플레이 스테이지 수:
#     설치 후 7일 동안 유저당 평균 플레이 스테이지 수
